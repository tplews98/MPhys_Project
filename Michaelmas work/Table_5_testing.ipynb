# %%
from astropy.table import Table
from astropy.table import Column
from astropy.io import fits
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# Import gz2 data as a table
filename = "GZ Data\zoo2MainSpecz_no_large_int.fits" # Table 5
gz2_data = Table.read(filename, format="fits")
print(gz2_data.info)
# Out:
# <Table masked=True length=243500>
#                              name                              dtype
# ------------------------------------------------------------- -------
#                                                            ra float32
#                                                           dec float32
#                                                      rastring bytes11
#                                                     decstring bytes11
#                                                        sample bytes20
#                                                      gz2class bytes20
#                                         total_classifications   int16
#                                                   total_votes   int16
#                       t01_smooth_or_features_a01_smooth_count   int16
#                      t01_smooth_or_features_a01_smooth_weight float32
#                    t01_smooth_or_features_a01_smooth_fraction float32
#           t01_smooth_or_features_a01_smooth_weighted_fraction float32
#                    t01_smooth_or_features_a01_smooth_debiased float32
#                        t01_smooth_or_features_a01_smooth_flag   int16
#             t01_smooth_or_features_a02_features_or_disk_count   int16
#            t01_smooth_or_features_a02_features_or_disk_weight float32
#          t01_smooth_or_features_a02_features_or_disk_fraction float32
# t01_smooth_or_features_a02_features_or_disk_weighted_fraction float32
#          t01_smooth_or_features_a02_features_or_disk_debiased float32
#              t01_smooth_or_features_a02_features_or_disk_flag   int16
#             t01_smooth_or_features_a03_star_or_artifact_count   int16
#            t01_smooth_or_features_a03_star_or_artifact_weight float32
#          t01_smooth_or_features_a03_star_or_artifact_fraction float32
# t01_smooth_or_features_a03_star_or_artifact_weighted_fraction float32
#          t01_smooth_or_features_a03_star_or_artifact_debiased float32
#              t01_smooth_or_features_a03_star_or_artifact_flag   int16
#                                      t02_edgeon_a04_yes_count   int16
#                                     t02_edgeon_a04_yes_weight float32
#                                   t02_edgeon_a04_yes_fraction float32
#                          t02_edgeon_a04_yes_weighted_fraction float32
#                                   t02_edgeon_a04_yes_debiased float32
#                                       t02_edgeon_a04_yes_flag   int16
#                                       t02_edgeon_a05_no_count   int16
#                                      t02_edgeon_a05_no_weight float32
#                                    t02_edgeon_a05_no_fraction float32
#                           t02_edgeon_a05_no_weighted_fraction float32
#                                    t02_edgeon_a05_no_debiased float32
#                                        t02_edgeon_a05_no_flag   int16
#                                         t03_bar_a06_bar_count   int16
#                                        t03_bar_a06_bar_weight float32
#                                      t03_bar_a06_bar_fraction float32
#                             t03_bar_a06_bar_weighted_fraction float32
#                                      t03_bar_a06_bar_debiased float32
#                                          t03_bar_a06_bar_flag   int16
#                                      t03_bar_a07_no_bar_count   int16
#                                     t03_bar_a07_no_bar_weight float32
#                                   t03_bar_a07_no_bar_fraction float32
#                          t03_bar_a07_no_bar_weighted_fraction float32
#                                   t03_bar_a07_no_bar_debiased float32
#                                       t03_bar_a07_no_bar_flag   int16
#                                   t04_spiral_a08_spiral_count   int16
#                                  t04_spiral_a08_spiral_weight float32
#                                t04_spiral_a08_spiral_fraction float32
#                       t04_spiral_a08_spiral_weighted_fraction float32
#                                t04_spiral_a08_spiral_debiased float32
#                                    t04_spiral_a08_spiral_flag   int16
#                                t04_spiral_a09_no_spiral_count   int16
#                               t04_spiral_a09_no_spiral_weight float32
#                             t04_spiral_a09_no_spiral_fraction float32
#                    t04_spiral_a09_no_spiral_weighted_fraction float32
#                             t04_spiral_a09_no_spiral_debiased float32
#                                 t04_spiral_a09_no_spiral_flag   int16
#                       t05_bulge_prominence_a10_no_bulge_count   int16
#                      t05_bulge_prominence_a10_no_bulge_weight float32
#                    t05_bulge_prominence_a10_no_bulge_fraction float32
#           t05_bulge_prominence_a10_no_bulge_weighted_fraction float32
#                    t05_bulge_prominence_a10_no_bulge_debiased float32
#                        t05_bulge_prominence_a10_no_bulge_flag   int16
#                t05_bulge_prominence_a11_just_noticeable_count   int16
#               t05_bulge_prominence_a11_just_noticeable_weight float32
#             t05_bulge_prominence_a11_just_noticeable_fraction float32
#    t05_bulge_prominence_a11_just_noticeable_weighted_fraction float32
#             t05_bulge_prominence_a11_just_noticeable_debiased float32
#                 t05_bulge_prominence_a11_just_noticeable_flag   int16
#                        t05_bulge_prominence_a12_obvious_count   int16
#                       t05_bulge_prominence_a12_obvious_weight float32
#                     t05_bulge_prominence_a12_obvious_fraction float32
#            t05_bulge_prominence_a12_obvious_weighted_fraction float32
#                     t05_bulge_prominence_a12_obvious_debiased float32
#                         t05_bulge_prominence_a12_obvious_flag   int16
#                       t05_bulge_prominence_a13_dominant_count   int16
#                      t05_bulge_prominence_a13_dominant_weight float32
#                    t05_bulge_prominence_a13_dominant_fraction float32
#           t05_bulge_prominence_a13_dominant_weighted_fraction float32
#                    t05_bulge_prominence_a13_dominant_debiased float32
#                        t05_bulge_prominence_a13_dominant_flag   int16
#                                         t06_odd_a14_yes_count   int16
#                                        t06_odd_a14_yes_weight float32
#                                      t06_odd_a14_yes_fraction float32
#                             t06_odd_a14_yes_weighted_fraction float32
#                                      t06_odd_a14_yes_debiased float32
#                                          t06_odd_a14_yes_flag   int16
#                                          t06_odd_a15_no_count   int16
#                                         t06_odd_a15_no_weight float32
#                                       t06_odd_a15_no_fraction float32
#                              t06_odd_a15_no_weighted_fraction float32
#                                       t06_odd_a15_no_debiased float32
#                                           t06_odd_a15_no_flag   int16
#                        t07_rounded_a16_completely_round_count   int16
#                       t07_rounded_a16_completely_round_weight float32
#                     t07_rounded_a16_completely_round_fraction float32
#            t07_rounded_a16_completely_round_weighted_fraction float32
#                     t07_rounded_a16_completely_round_debiased float32
#                         t07_rounded_a16_completely_round_flag   int16
#                              t07_rounded_a17_in_between_count   int16
#                             t07_rounded_a17_in_between_weight float32
#                           t07_rounded_a17_in_between_fraction float32
#                  t07_rounded_a17_in_between_weighted_fraction float32
#                           t07_rounded_a17_in_between_debiased float32
#                               t07_rounded_a17_in_between_flag   int16
#                            t07_rounded_a18_cigar_shaped_count   int16
#                           t07_rounded_a18_cigar_shaped_weight float32
#                         t07_rounded_a18_cigar_shaped_fraction float32
#                t07_rounded_a18_cigar_shaped_weighted_fraction float32
#                         t07_rounded_a18_cigar_shaped_debiased float32
#                             t07_rounded_a18_cigar_shaped_flag   int16
#                                t08_odd_feature_a19_ring_count   int16
#                               t08_odd_feature_a19_ring_weight float32
#                             t08_odd_feature_a19_ring_fraction float32
#                    t08_odd_feature_a19_ring_weighted_fraction float32
#                             t08_odd_feature_a19_ring_debiased float32
#                                 t08_odd_feature_a19_ring_flag   int16
#                         t08_odd_feature_a20_lens_or_arc_count   int16
#                        t08_odd_feature_a20_lens_or_arc_weight float32
#                      t08_odd_feature_a20_lens_or_arc_fraction float32
#             t08_odd_feature_a20_lens_or_arc_weighted_fraction float32
#                      t08_odd_feature_a20_lens_or_arc_debiased float32
#                          t08_odd_feature_a20_lens_or_arc_flag   int16
#                           t08_odd_feature_a21_disturbed_count   int16
#                          t08_odd_feature_a21_disturbed_weight float32
#                        t08_odd_feature_a21_disturbed_fraction float32
#               t08_odd_feature_a21_disturbed_weighted_fraction float32
#                        t08_odd_feature_a21_disturbed_debiased float32
#                            t08_odd_feature_a21_disturbed_flag   int16
#                           t08_odd_feature_a22_irregular_count   int16
#                          t08_odd_feature_a22_irregular_weight float32
#                        t08_odd_feature_a22_irregular_fraction float32
#               t08_odd_feature_a22_irregular_weighted_fraction float32
#                        t08_odd_feature_a22_irregular_debiased float32
#                            t08_odd_feature_a22_irregular_flag   int16
#                               t08_odd_feature_a23_other_count   int16
#                              t08_odd_feature_a23_other_weight float32
#                            t08_odd_feature_a23_other_fraction float32
#                   t08_odd_feature_a23_other_weighted_fraction float32
#                            t08_odd_feature_a23_other_debiased float32
#                                t08_odd_feature_a23_other_flag   int16
#                              t08_odd_feature_a24_merger_count   int16
#                             t08_odd_feature_a24_merger_weight float32
#                           t08_odd_feature_a24_merger_fraction float32
#                  t08_odd_feature_a24_merger_weighted_fraction float32
#                           t08_odd_feature_a24_merger_debiased float32
#                               t08_odd_feature_a24_merger_flag   int16
#                           t08_odd_feature_a38_dust_lane_count   int16
#                          t08_odd_feature_a38_dust_lane_weight float32
#                        t08_odd_feature_a38_dust_lane_fraction float32
#               t08_odd_feature_a38_dust_lane_weighted_fraction float32
#                        t08_odd_feature_a38_dust_lane_debiased float32
#                            t08_odd_feature_a38_dust_lane_flag   int16
#                             t09_bulge_shape_a25_rounded_count   int16
#                            t09_bulge_shape_a25_rounded_weight float32
#                          t09_bulge_shape_a25_rounded_fraction float32
#                 t09_bulge_shape_a25_rounded_weighted_fraction float32
#                          t09_bulge_shape_a25_rounded_debiased float32
#                              t09_bulge_shape_a25_rounded_flag   int16
#                                t09_bulge_shape_a26_boxy_count   int16
#                               t09_bulge_shape_a26_boxy_weight float32
#                             t09_bulge_shape_a26_boxy_fraction float32
#                    t09_bulge_shape_a26_boxy_weighted_fraction float32
#                             t09_bulge_shape_a26_boxy_debiased float32
#                                 t09_bulge_shape_a26_boxy_flag   int16
#                            t09_bulge_shape_a27_no_bulge_count   int16
#                           t09_bulge_shape_a27_no_bulge_weight float32
#                         t09_bulge_shape_a27_no_bulge_fraction float32
#                t09_bulge_shape_a27_no_bulge_weighted_fraction float32
#                         t09_bulge_shape_a27_no_bulge_debiased float32
#                             t09_bulge_shape_a27_no_bulge_flag   int16
#                              t10_arms_winding_a28_tight_count   int16
#                             t10_arms_winding_a28_tight_weight float32
#                           t10_arms_winding_a28_tight_fraction float32
#                  t10_arms_winding_a28_tight_weighted_fraction float32
#                           t10_arms_winding_a28_tight_debiased float32
#                               t10_arms_winding_a28_tight_flag   int16
#                             t10_arms_winding_a29_medium_count   int16
#                            t10_arms_winding_a29_medium_weight float32
#                          t10_arms_winding_a29_medium_fraction float32
#                 t10_arms_winding_a29_medium_weighted_fraction float32
#                          t10_arms_winding_a29_medium_debiased float32
#                              t10_arms_winding_a29_medium_flag   int16
#                              t10_arms_winding_a30_loose_count   int16
#                             t10_arms_winding_a30_loose_weight float32
#                           t10_arms_winding_a30_loose_fraction float32
#                  t10_arms_winding_a30_loose_weighted_fraction float32
#                           t10_arms_winding_a30_loose_debiased float32
#                               t10_arms_winding_a30_loose_flag   int16
#                                   t11_arms_number_a31_1_count   int16
#                                  t11_arms_number_a31_1_weight float32
#                                t11_arms_number_a31_1_fraction float32
#                       t11_arms_number_a31_1_weighted_fraction float32
#                                t11_arms_number_a31_1_debiased float32
#                                    t11_arms_number_a31_1_flag   int16
#                                   t11_arms_number_a32_2_count   int16
#                                  t11_arms_number_a32_2_weight float32
#                                t11_arms_number_a32_2_fraction float32
#                       t11_arms_number_a32_2_weighted_fraction float32
#                                t11_arms_number_a32_2_debiased float32
#                                    t11_arms_number_a32_2_flag   int16
#                                   t11_arms_number_a33_3_count   int16
#                                  t11_arms_number_a33_3_weight float32
#                                t11_arms_number_a33_3_fraction float32
#                       t11_arms_number_a33_3_weighted_fraction float32
#                                t11_arms_number_a33_3_debiased float32
#                                    t11_arms_number_a33_3_flag   int16
#                                   t11_arms_number_a34_4_count   int16
#                                  t11_arms_number_a34_4_weight float32
#                                t11_arms_number_a34_4_fraction float32
#                       t11_arms_number_a34_4_weighted_fraction float32
#                                t11_arms_number_a34_4_debiased float32
#                                    t11_arms_number_a34_4_flag   int16
#                         t11_arms_number_a36_more_than_4_count   int16
#                        t11_arms_number_a36_more_than_4_weight float32
#                      t11_arms_number_a36_more_than_4_fraction float32
#             t11_arms_number_a36_more_than_4_weighted_fraction float32
#                      t11_arms_number_a36_more_than_4_debiased float32
#                          t11_arms_number_a36_more_than_4_flag   int16
#                           t11_arms_number_a37_cant_tell_count   int16
#                          t11_arms_number_a37_cant_tell_weight float32
#                        t11_arms_number_a37_cant_tell_fraction float32
#               t11_arms_number_a37_cant_tell_weighted_fraction float32
#                        t11_arms_number_a37_cant_tell_debiased float32
#                            t11_arms_number_a37_cant_tell_flag   int16

# %%
# Filter out debiased merger fraction only
merger_debiased = Table([gz2_data["t08_odd_feature_a24_merger_debiased"]])
merger_debiased["t08_odd_feature_a24_merger_debiased"].name = "Merger Fraction Debiased"
merger_debiased.info
# Out:
# <Table masked=True length=243500>
#           name            dtype
# ------------------------ -------
# Merger Fraction Debiased float32

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,5))

# Plot histogram of entire gz2 data merger fraction
ax[0].hist(merger_debiased["Merger Fraction Debiased"],  bins=10, range=(0,1), edgecolor="black")
ax[0].set_xlabel("Merger Fraction")
ax[0].set_ylabel("Number of Galaxies")
ax[0].set_title("Number of Galaxies vs Merger Fraction Debiased")

# Plot historgram of gz2 data with non zero merger fraction
merger_debiased_nonzero = merger_debiased[merger_debiased["Merger Fraction Debiased"] > 0]
ax[1].hist(merger_debiased_nonzero["Merger Fraction Debiased"], bins=10, range=(0,1), edgecolor="black")
ax[1].set_xlabel("Merger Fraction")
ax[1].set_ylabel("Number of Galaxies")
ax[1].set_title("Galaxies vs Merger Fraction Debiased with only $f_{merger} > 0$")
fig.subplots_adjust(wspace=0.3)

# %%
# Plot same second graph as above with labels for number of galaxies in bin
num_of_bins = 10
fig2 = plt.hist(merger_debiased_nonzero["Merger Fraction Debiased"], bins=num_of_bins, range=(0,1), edgecolor="black")
plt.xlabel("Merger Fraction")
plt.ylabel("Number of Galaxies")
plt.title("Merger Fraction Debiased with only $f_{merger} > 0$")
plt.ylim(0, max(fig2[0])*1.1)
for i in range(num_of_bins):
    plt.text((fig2[1][i] + fig2[1][i+1]) / 2,fig2[0][i]+500,str(int(fig2[0][i])), fontsize=9, ha='center')
plt.show()

# %%
# Resample data for only galaxies which have merger_flag = 1, and that have a minimum number of merger votes

# greater_than_1 = gz2_data[gz2_data["t08_odd_feature_a24_merger_count"] > 1]
# mergers = greater_than_1[greater_than_1["t08_odd_feature_a24_merger_debiased"] == 1]

# mergers = gz2_data[gz2_data["t08_odd_feature_a24_merger_flag"] == 1]
mergers = Table(gz2_data)
mergers = mergers[mergers["t08_odd_feature_a24_merger_count"] >= 10]
print(len(mergers))
# Out:
# 9158

# %%
num_of_bins = 10
fig3 = plt.hist(mergers["t08_odd_feature_a24_merger_debiased"], bins=num_of_bins, range=(0,1), edgecolor="black")
plt.xlabel("Merger Fraction")
plt.ylabel("Number of Galaxies")
plt.title("Merger Fraction Debiased with merger_votes > 10")
plt.ylim(0, max(fig3[0])*1.1)
for i in range(num_of_bins):
    plt.text((fig3[1][i] + fig3[1][i+1]) / 2,fig3[0][i]+50,str(int(fig3[0][i])), fontsize=9, ha='center')
plt.show()

# %%
import random

mergers_index = random.randint(0, len(mergers))

url1 = "http://skyservice.pha.jhu.edu/DR7/ImgCutout/getjpeg.aspx?ra="
ra = mergers["ra"][mergers_index]
url2 = "&dec="
dec = mergers["dec"][mergers_index]
url3 = "&scale=0.39612&width=400&height=400&opt=&query="
url = url1 + str(ra) + url2 + str(dec) + url3
print(url)

import urllib.request
from PIL import Image
image = Image.open(urllib.request.urlopen(url))
image
# Out:
# http://skyservice.pha.jhu.edu/DR7/ImgCutout/getjpeg.aspx?ra=207.57152&dec=29.24685&scale=0.39612&width=400&height=400&opt=&query=
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x2003CC52CC0>

# %%
# anything_odd_yes = gz2_data[gz2_data["t06_odd_a14_yes_flag" == 1]]
print(len(gz2_data[gz2_data["t06_odd_a14_yes_flag"] == 1]))
print(len(gz2_data[gz2_data["t06_odd_a14_yes_debiased"] >= 0.8])) # not the same length, different thresholds used
# print((gz2_data[gz2_data["t06_odd_a14_yes_flag"] == 1] == gz2_data[gz2_data["t06_odd_a14_yes_debiased"] > 0.8]).all())

print(len(gz2_data[gz2_data["t08_odd_feature_a24_merger_flag"] == 1]))
print(len(gz2_data[gz2_data["t08_odd_feature_a24_merger_debiased"] >= 0.8]))# not the same length, different thresholds used
# print((gz2_data[gz2_data["t08_odd_feature_a24_merger_flag"] == 1] == gz2_data[gz2_data["t08_odd_feature_a24_merger_debiased"] >= 0.8]).all())
# merger flag does either consider merger votes or "anything odd" votes, unlike Table 1, hence we see different plots
# Out:
# 7368
# 7377
# 513
# 2440
